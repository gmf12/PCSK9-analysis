# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
#798

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Pro\\PCSK9_PCA_prodo_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1:1005:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "silver", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-150, 150)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('wt-maestro_pro.pdf', dpi=600)

# %%
#831

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Pro\\PCSK9_PCA_prodo_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1006:2010:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#4E8AA3", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-150, 150)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('E32K-maestro_pro.pdf', dpi=600)

# %%
#832

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Pro\\PCSK9_PCA_prodo_PCA_proj.csv") 
PCA_WT=PCA_full.loc[2011:3015:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#F0CB5B", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-150, 150)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('E57K-maestro_pro.pdf', dpi=600)

# %%
#798

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1:1005:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "gray", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('wt-maestro_cata.pdf', dpi=600)

# %%
#833

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1006:2010:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#894FF0", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R237W-maestro_cat.pdf', dpi=600)

# %%
#834

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[2011:3015:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#A36258", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('P279T-maestro_cat.pdf', dpi=600)

# %%
#835

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[3016:4020:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#7DF0D4", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('A443T-maestro_cat.pdf', dpi=600)

# %%
#836

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[4021:5025:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "magenta", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R469W-maestro_cat.pdf', dpi=600)

# %%
#837

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[5026:6030:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#1A5CA3", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)


flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Q619P-maestro_cat.pdf', dpi=600)

# %%
#838

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Cata\\PCSK9_PCA_cat_PCA_proj.csv") 
PCA_WT=PCA_full.loc[6031:7035:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "salmon", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-60, 60)
plot.ax_marg_y.set_ylim(-60, 70)


flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R680Q-maestro_cat.pdf', dpi=600)

# %%
#798

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1:1005:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "gray", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('wt-maestro_full.pdf', dpi=600)

# %%
#831

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[1006:2010:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#4E8AA3", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('E32K-maestro_full.pdf', dpi=600)

# %%
#832

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[2011:3015:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#F0CB5B", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('E57K-maestro_ful.pdf', dpi=600)

# %%
#833

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[3016:4020:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#894FF0", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R237W-maestro_ful.pdf', dpi=600)

# %%
#834

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[4021:5025:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#A36258", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('P279T-maestro_ful.pdf', dpi=600)

# %%
#835

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[5026:6030:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#7DF0D4", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('A443T-maestro_ful.pdf', dpi=600)

# %%
#836

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[6031:7035:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "magenta", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)



flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R469W-maestro_ful.pdf', dpi=600)

# %%
#837

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[7036:8040:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "#1A5CA3", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)


flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Q619P-maestro_ful.pdf', dpi=600)

# %%
#838

PCA_full=pd.read_csv("C:\\Users\\glauc\\OneDrive\\Pcsk9-paper\\PCSK9-modelling_gmf\\Model\\MD\\SIDs\\PCA\\maestro\\Full\\PCSK9_PCA_merged_full_PCA_proj.csv") 
PCA_WT=PCA_full.loc[8041:9045:1]




#generate some random date
#x = np.random.normal(loc=650, scale=100, size=1000)
#y = np.random.normal(loc=600, scale=200, size=1000)

plot = sns.jointplot(x="PC_1", y="PC_2", data= PCA_WT, color = "salmon", kind="kde", fill=True)
plot.ax_marg_x.set_xlim(-250, 250)
plot.ax_marg_y.set_ylim(-150, 150)


flatui = ["#4E8AA3", "#67C7F0","#F0CB5B","#582EA3","#894FF0","#A36258","#F0D83A","#7DF0D4","#1A5CA3","#F044BD","#59A39B"]

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('R680Q-maestro_ful.pdf', dpi=600)
